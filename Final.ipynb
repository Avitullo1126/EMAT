# %% [markdown]
# I decided to find 2 stat sheets one for Lebron and one for Jordan which often sparks large debates so I decided to compare both of their usage percentagtes and field goal percentage for the first 7 years of their carrers
#
# My first attempts

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Here I imported both of my stat sheets

# %%
lj = pd.read_csv('advanced_stats.csv')

# %%
mj= pd.read_csv('advanced_stats2.csv')

# %%
lj.head(8)
# Out:
#     Season  Age   Tm   Lg Pos   G    MP   PER    TS%   3PAr  ...   OWS  DWS  \
# 0  2003-04   19  CLE  NBA  SG  79  3122  18.3  0.488  0.145  ...   2.4  2.6
# 1  2004-05   20  CLE  NBA  SF  80  3388  25.7  0.554  0.183  ...   9.7  4.6
# 2  2005-06   21  CLE  NBA  SF  79  3361  28.1  0.568  0.208  ...  12.0  4.3
# 3  2006-07   22  CLE  NBA  SF  78  3190  24.5  0.552  0.191  ...   8.0  5.7
# 4  2007-08   23  CLE  NBA  SF  75  3027  29.1  0.568  0.219  ...  10.7  4.6
# 5  2008-09   24  CLE  NBA  SF  81  3054  31.7  0.591  0.238  ...  13.7  6.5
# 6  2009-10   25  CLE  NBA  SF  76  2966  31.1  0.604  0.253  ...  13.3  5.2
# 7  2010-11   26  MIA  NBA  SF  79  3063  27.3  0.594  0.188  ...  10.3  5.3
#
#      WS  WS/48  OBPM  DBPM   BPM  VORP        Player          RSorPO
# 0   5.1  0.078   2.2  -0.2   1.9   3.1  Lebron James  Regular Season
# 1  14.3  0.203   6.9   1.5   8.3   8.8  Lebron James  Regular Season
# 2  16.3  0.232   7.9   1.4   9.3   9.5  Lebron James  Regular Season
# ...

# %%
lj.columns
# Out:
# Index(['Season', 'Age', 'Tm', 'Lg', 'Pos', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'Player',
#        'RSorPO'],
#       dtype='object')

# %%
lj = pd.read_csv('advanced_stats.csv', index_col=['Player'])
lj.iloc()
lj.head(8)
# Out:
#                Season  Age   Tm   Lg Pos   G    MP   PER    TS%   3PAr  ...  \
# Player                                                                  ...
# Lebron James  2003-04   19  CLE  NBA  SG  79  3122  18.3  0.488  0.145  ...
# Lebron James  2004-05   20  CLE  NBA  SF  80  3388  25.7  0.554  0.183  ...
# Lebron James  2005-06   21  CLE  NBA  SF  79  3361  28.1  0.568  0.208  ...
# Lebron James  2006-07   22  CLE  NBA  SF  78  3190  24.5  0.552  0.191  ...
# Lebron James  2007-08   23  CLE  NBA  SF  75  3027  29.1  0.568  0.219  ...
# Lebron James  2008-09   24  CLE  NBA  SF  81  3054  31.7  0.591  0.238  ...
# Lebron James  2009-10   25  CLE  NBA  SF  76  2966  31.1  0.604  0.253  ...
# Lebron James  2010-11   26  MIA  NBA  SF  79  3063  27.3  0.594  0.188  ...
#
#               USG%   OWS  DWS    WS  WS/48  OBPM  DBPM   BPM  VORP  \
# Player
# Lebron James  28.2   2.4  2.6   5.1  0.078   2.2  -0.2   1.9   3.1
# ...

# %% [markdown]
# Here I repeat the same process as before but with Michael Jordan this time

# %%
mj.head(8)
# Out:
#     Season  Age   Tm   Lg Pos  USG%   G    MP   PER    TS%  ...   OWS  DWS  \
# 0  1984-85   21  CHI  NBA  SG  29.8  82  3144  25.8  0.592  ...  10.3  3.7
# 1  1985-86   22  CHI  NBA  SG  38.6  18   451  27.5  0.533  ...   1.0  0.5
# 2  1986-87   23  CHI  NBA  SG  38.3  82  3281  29.8  0.562  ...  11.9  5.0
# 3  1987-88   24  CHI  NBA  SG  34.1  82  3311  31.7  0.603  ...  15.2  6.1
# 4  1988-89   25  CHI  NBA  SG  32.1  81  3255  31.1  0.614  ...  14.6  5.2
# 5  1989-90   26  CHI  NBA  SG  33.7  82  3197  31.2  0.606  ...  14.7  4.3
# 6  1990-91   27  CHI  NBA  SG  32.9  82  3034  31.6  0.605  ...  14.9  5.4
# 7  1991-92   28  CHI  NBA  SG  31.7  80  3102  27.7  0.579  ...  12.1  5.6
#
#      WS  WS/48  OBPM  DBPM   BPM  VORP          Player          RSorPO
# 0  14.0  0.213   6.8   1.4   8.2   8.1  Michael Jordan  Regular Season
# 1   1.5  0.160   5.1  -0.5   4.7   0.8  Michael Jordan  Regular Season
# 2  16.9  0.247   8.0   0.6   8.6   8.8  Michael Jordan  Regular Season
# ...

# %% [markdown]
# Here I make sure that they both have the same columns and they are visible

# %%
mj.columns
# Out:
# Index(['Season', 'Age', 'Tm', 'Lg', 'Pos', 'USG%', 'G', 'MP', 'PER', 'TS%',
#        '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%',
#        'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'Player',
#        'RSorPO'],
#       dtype='object')

# %%
mJ = pd.read_csv('advanced_stats2.csv', index_col=['Player'])
mj.iloc()
mj.head(8)
# Out:
#     Season  Age   Tm   Lg Pos  USG%   G    MP   PER    TS%  ...   OWS  DWS  \
# 0  1984-85   21  CHI  NBA  SG  29.8  82  3144  25.8  0.592  ...  10.3  3.7
# 1  1985-86   22  CHI  NBA  SG  38.6  18   451  27.5  0.533  ...   1.0  0.5
# 2  1986-87   23  CHI  NBA  SG  38.3  82  3281  29.8  0.562  ...  11.9  5.0
# 3  1987-88   24  CHI  NBA  SG  34.1  82  3311  31.7  0.603  ...  15.2  6.1
# 4  1988-89   25  CHI  NBA  SG  32.1  81  3255  31.1  0.614  ...  14.6  5.2
# 5  1989-90   26  CHI  NBA  SG  33.7  82  3197  31.2  0.606  ...  14.7  4.3
# 6  1990-91   27  CHI  NBA  SG  32.9  82  3034  31.6  0.605  ...  14.9  5.4
# 7  1991-92   28  CHI  NBA  SG  31.7  80  3102  27.7  0.579  ...  12.1  5.6
#
#      WS  WS/48  OBPM  DBPM   BPM  VORP          Player          RSorPO
# 0  14.0  0.213   6.8   1.4   8.2   8.1  Michael Jordan  Regular Season
# 1   1.5  0.160   5.1  -0.5   4.7   0.8  Michael Jordan  Regular Season
# 2  16.9  0.247   8.0   0.6   8.6   8.8  Michael Jordan  Regular Season
# ...

# %% [markdown]
# Started generating the graphs

# %%
fig1, ax1 = plt.subplots(1, 2, )
ax1[0].hist(lj['USG%'])
ax1[1].hist(lj['TS%'])

plt.show()

# %%
fig2, ax2 = plt.subplots()
ax2.scatter(x = lj['USG%'],
            y = lj['TS%'])

plt.show()

# %%
fig3, ax3 = plt.subplots()
ax3.scatter(x = mj['USG%'],
            y = mj['TS%'])

plt.show()

# %% [markdown]
# Here I combined both of the stat sheets

# %%
both= pd.read_csv('advanced_stats3.csv')
both.head(8)
# Out:
#     Season  Age   Tm   Lg Pos   G    MP   PER    TS%   3PAr  ...   OWS  DWS  \
# 0  2003-04   19  CLE  NBA  SG  79  3122  18.3  0.488  0.145  ...   2.4  2.6
# 1  2004-05   20  CLE  NBA  SF  80  3388  25.7  0.554  0.183  ...   9.7  4.6
# 2  2005-06   21  CLE  NBA  SF  79  3361  28.1  0.568  0.208  ...  12.0  4.3
# 3  2006-07   22  CLE  NBA  SF  78  3190  24.5  0.552  0.191  ...   8.0  5.7
# 4  2007-08   23  CLE  NBA  SF  75  3027  29.1  0.568  0.219  ...  10.7  4.6
# 5  2008-09   24  CLE  NBA  SF  81  3054  31.7  0.591  0.238  ...  13.7  6.5
# 6  2009-10   25  CLE  NBA  SF  76  2966  31.1  0.604  0.253  ...  13.3  5.2
# 7  2010-11   26  MIA  NBA  SF  79  3063  27.3  0.594  0.188  ...  10.3  5.3
#
#      WS  WS/48  OBPM  DBPM   BPM  VORP        Player          RSorPO
# 0   5.1  0.078   2.2  -0.2   1.9   3.1  Lebron James  Regular Season
# 1  14.3  0.203   6.9   1.5   8.3   8.8  Lebron James  Regular Season
# 2  16.3  0.232   7.9   1.4   9.3   9.5  Lebron James  Regular Season
# ...

# %% [markdown]
# Making the graph that I am going to use

# %% [markdown]
# Lebron James graph

# %%
fig2, ax2 = plt.subplots(1, 2)
ax2[0].hist(lj['TS%'])
ax2[1].hist(lj['USG%'])

plt.show()

# %% [markdown]
# Michel Jordan graph

# %%
fig1, ax1 = plt.subplots(1, 2)
ax1[0].hist(mj['TS%'])
ax1[1].hist(mj['USG%'])

plt.show()

# %% [markdown]
# Now after looking at both graphs we can see that Michael Jordan has the best point average while playing on the floor
